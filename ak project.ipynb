# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # import csv file

# %%
df = pd.read_csv('all timebest movie - IMDb.csv', engine='python')

# %%
df
# Out:
#      Unnamed: 0                  title  year  rating  metascore certificate  \
# 0             0        Soorarai Pottru  2020     8.6         65           U
# 1             1               Gol Maal  1979     8.6         50           U
# 2             2            Vada Chen0i  2018     8.5         85          18
# 3             3           Black Friday  2004     8.5         76    (Banned)
# 4             4                 Dangal  2016     8.4         76           U
# ..          ...                    ...   ...     ...        ...         ...
# 374         374                 Gunday  2014     2.4          0          UA
# 375         375                 Laxmii  2020     2.3          0         15+
# 376         376  Student of the Year 2  2019     2.2          0          UA
# 377         377                 Race 3  2018     1.9          0          UA
# 378         378                Sadak 2  2020     1.1          0         15+
#
#         votes  runtime                                 gener  \
# 0      58,066      153                     Drama
# 1      18,125      144           Comedy, Romance
# 2      11,619      164      Action, Crime, Drama
# 3      19,080      143      Action, Crime, Drama
# 4    1,60,469      161  Action, Biography, Drama
# ..        ...      ...                                   ...
# 374    57,908      152    Action, Drama, Musical
# 375    47,092      141    Action, Comedy, Horror
# 376    16,732      146    Action, Drama, Romance
# 377    34,637      160   Action, Crime, Thriller
# 378    65,410      133             Action, Drama
#
#                  director               star1            star2  \
# 0           Sudha Kongara              Suriya         Madhavan
# 1    Hrishikesh Mukherjee        Amol Palekar  Bindiya Goswami
# 2             Vetrimaaran             Dhanush     Ameer Sultan
# 3          Anurag Kashyap       Kay Kay Menon   Pawan Malhotra
# 4           Nitesh Tiwari          Aamir Khan    Sakshi Tanwar
# ..                    ...                 ...              ...
# 374       Ali Abbas Zafar       Ranveer Singh     Arjun Kapoor
# 375  Lawrence Raghavendra  Balakrish0n Thevar     Akshay Kumar
# 376        Punit Malhotra        Tiger Shroff     A0nya Panday
# 377          Remo D'Souza         Anil Kapoor      Salman Khan
# 378          Mahesh Bhatt          Alia Bhatt    Priyanka Bose
#
#                  star3                  star4    gross
# 0     Apar0 Balamurali           Paresh Rawal        0
# 1          Deven Verma           Shubha Khote        0
# 2           Radha Ravi          Daniel Balaji        0
# 3     Aditya Srivastav  Dibyendu Bhattacharya   $0.03M
# 4    Fatima Sa0 Shaikh         Sanya Malhotra  $12.39M
# ..                 ...                    ...      ...
# 374    Priyanka Chopra            Irrfan Khan        0
# 375       Kiara Advani          Sharad Kelkar        0
# 376       Tara Sutaria            Aditya Seal   $0.78M
# 377         Bobby Deol    Jacqueline Fer0ndez   $1.69M
# 378        Sanjay Dutt            Pooja Bhatt        0
#
# [379 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   379 non-null    int64
#  1   title        379 non-null    object
#  2   year         352 non-null    object
#  3   rating       379 non-null    float64
#  4   metascore    379 non-null    int64
#  5   certificate  379 non-null    object
#  6   votes        379 non-null    object
#  7   runtime      379 non-null    int64
#  8   gener        379 non-null    object
#  9   director     379 non-null    object
#  10  star1        379 non-null    object
#  11  star2        379 non-null    object
#  12  star3        379 non-null    object
#  13  star4        379 non-null    object
#  14  gross        379 non-null    object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 44.5+ KB

# %% [markdown]
# # RATINGS

# %%
df1=df.sort_values('rating',ascending=[False]).head(10)
df1.index= np.arange(1,11)
df1
# Out:
#     Unnamed: 0               title  year  rating  metascore certificate  \
# 1            0     Soorarai Pottru  2020     8.6         65           U
# 2            1            Gol Maal  1979     8.6         50           U
# 3            2         Vada Chen0i  2018     8.5         85          18
# 4            3        Black Friday  2004     8.5         76    (Banned)
# 5            4              Dangal  2016     8.4         76           U
# 6            5            3 Idiots  2009     8.4         67          UA
# 7            6    Taare Zameen Par  2007     8.4         70           U
# 8            7  Jaane Bhi Do Yaaro  1983     8.4          0           U
# 9           10       Chupke Chupke  1975     8.3          0           U
# 10          11                A0nd  1971     8.3          0           U
#
#        votes  runtime                                 gener  \
# 1     58,066      153                     Drama
# 2     18,125      144           Comedy, Romance
# 3     11,619      164      Action, Crime, Drama
# 4     19,080      143      Action, Crime, Drama
# 5   1,60,469      161  Action, Biography, Drama
# 6   3,50,102      170             Comedy, Drama
# 7   1,72,353      165             Drama, Family
# 8     13,311      132      Comedy, Crime, Drama
# 9     11,736      146    Comedy, Drama, Romance
# 10    31,105      122            Drama, Musical
#
#                 director            star1             star2  \
# 1          Sudha Kongara           Suriya          Madhavan
# 2   Hrishikesh Mukherjee     Amol Palekar   Bindiya Goswami
# 3            Vetrimaaran          Dhanush      Ameer Sultan
# 4         Anurag Kashyap    Kay Kay Menon    Pawan Malhotra
# 5          Nitesh Tiwari       Aamir Khan     Sakshi Tanwar
# 6        Rajkumar Hirani       Aamir Khan          Madhavan
# 7             Aamir Khan      Amole Gupte   Darsheel Safary
# 8            Kundan Shah  0seeruddin Shah      Ravi Baswani
# 9   Hrishikesh Mukherjee       Dharmendra   Sharmila Tagore
# 10  Hrishikesh Mukherjee     Rajesh Khan0  Amitabh Bachchan
#
#                 star3                  star4    gross
# 1    Apar0 Balamurali           Paresh Rawal        0
# 2         Deven Verma           Shubha Khote        0
# 3          Radha Ravi          Daniel Balaji        0
# 4    Aditya Srivastav  Dibyendu Bhattacharya   $0.03M
# 5   Fatima Sa0 Shaikh         Sanya Malhotra  $12.39M
# 6           Mo0 Singh          Sharman Joshi   $6.53M
# 7          Aamir Khan           Tisca Chopra   $1.22M
# 8        Bhakti Barve            Satish Shah        0
# 9    Amitabh Bachchan          Jaya Bachchan        0
# 10      Sumita Sanyal             Ramesh Deo        0

# %%
df1=df.sort_values('rating',ascending=[False]).tail(10)
df1.index= np.arange(1,11)
df1
# Out:
#     Unnamed: 0                  title  year  rating  metascore certificate  \
# 1          369              Dabangg 3  2019     3.2          0          UA
# 2          370       Veere Di Wedding  2018     3.2          0           A
# 3          371           Coolie No. 1  2020     2.9          0          UA
# 4          372         Tees Maar Khan  2010     2.6          0          UA
# 5          373   Dragonball Evolution  2009     2.5         45           U
# 6          374                 Gunday  2014     2.4          0          UA
# 7          375                 Laxmii  2020     2.3          0         15+
# 8          376  Student of the Year 2  2019     2.2          0          UA
# 9          377                 Race 3  2018     1.9          0          UA
# 10         378                Sadak 2  2020     1.1          0         15+
#
#      votes  runtime                                   gener  \
# 1   10,608      160              Action, Comedy
# 2   11,845      135                      Comedy
# 3   55,242      134     Action, Comedy, Romance
# 4   11,607      135               Comedy, Crime
# 5   70,822       85  Action, Adventure, Fantasy
# 6   57,908      152      Action, Drama, Musical
# 7   47,092      141      Action, Comedy, Horror
# 8   16,732      146      Action, Drama, Romance
# 9   34,637      160     Action, Crime, Thriller
# 10  65,410      133               Action, Drama
#
#                 director               star1           star2            star3  \
# 1            Prabhu Deva         Salman Khan          Sudeep    So0kshi Sinha
# 2        Shashanka Ghosh       Karee0 Kapoor     So0m Kapoor    Ekavali Khan0
# 3           David Dhawan        Varun Dhawan   Sara Ali Khan     Paresh Rawal
# 4             Farah Khan        Akshay Kumar     Katri0 Kaif    Akshaye Khan0
# 5             James Wong      Justin Chatwin  James Marsters     Chow Yun-Fat
# 6        Ali Abbas Zafar       Ranveer Singh    Arjun Kapoor  Priyanka Chopra
# 7   Lawrence Raghavendra  Balakrish0n Thevar    Akshay Kumar     Kiara Advani
# 8         Punit Malhotra        Tiger Shroff    A0nya Panday     Tara Sutaria
# 9           Remo D'Souza         Anil Kapoor     Salman Khan       Bobby Deol
# 10          Mahesh Bhatt          Alia Bhatt   Priyanka Bose      Sanjay Dutt
#
#                   star4   gross
# 1       Saiee Manjrekar       0
# 2         Swara Bhaskar       0
# 3         Javed Jaffrey       0
# 4          Rajiv Laxman  $1.08M
# 5           Emmy Rossum  $9.35M
# 6           Irrfan Khan       0
# 7         Sharad Kelkar       0
# 8           Aditya Seal  $0.78M
# 9   Jacqueline Fer0ndez  $1.69M
# 10          Pooja Bhatt       0

# %%
ratings=df.groupby(["title",'votes'])["rating"].sum()

# %%
average_rating=df['rating'].mean()
average_rating
# Out:
# 6.987598944591021

# %%
ratings=ratings.reset_index()
ratings
# Out:
#                        title     votes  rating
# 0             0mastey London    20,712     7.1
# 1        0yak: The Real Hero    14,543     7.8
# 2                          2    21,387     6.2
# 3                   2 States    23,679     6.9
# 4                       2012  3,56,644     5.8
# ..                       ...       ...     ...
# 374  Yeh Jawaani Hai Deewani    38,870     7.1
# 375                 Yes Boss    12,551     6.8
# 376                     Zero    23,924     5.4
# 377  Zindagi 0 Milegi Dobara    68,816     8.2
# 378   Zombieland: Double Tap  1,44,516     6.7
#
# [379 rows x 3 columns]

# %%
ratings["rating"].max()
# Out:
# 8.6

# %%
ratings["rating"].min()
# Out:
# 1.1

# %% [markdown]
# ### list of head 10 movie having rating above the avg rating

# %%
ratings[ratings["rating"]>=average_rating].head(10)
# Out:
#                   title     votes  rating
# 0        0mastey London    20,712     7.1
# 1   0yak: The Real Hero    14,543     7.8
# 5              3 Idiots  3,50,102     8.4
# 7    A Passage to India    17,199     7.3
# 8           A Wednesday    74,321     8.1
# 9                  A0nd    31,105     8.3
# 10             AK vs AK    11,660     7.0
# 11                Aamir    10,729     7.7
# 12              Aankhen    12,411     7.4
# 13           Aashiqui 2    26,914     7.0

# %% [markdown]
# ### list of head 10 movie having rating below the avg rating

# %%
ratings[ratings["rating"]<average_rating].head(10)
# Out:
#                           title     votes  rating
# 2                             2    21,387     6.2
# 3                      2 States    23,679     6.9
# 4                          2012  3,56,644     5.8
# 6        A Good Day to Die Hard  1,99,409     5.3
# 14           Ae Dil Hai Mushkil    21,305     5.8
# 15                    Agneepath    22,560     6.9
# 17   Ajab Prem Ki Ghazab Kahani    12,863     6.4
# 22  Around the World in 80 Days    85,816     5.9
# 24                        Asoka    13,349     6.5
# 26                     Baadshah    16,978     6.9

# %%
plt.figure(figsize=(15,5))
df["rating"].value_counts().plot(kind="bar") # pandas barplot
plt.ylabel("count")
plt.xlabel("rating")
plt.show()

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.kdeplot(df['rating'])
g.set_title("rating of all movies", weight = "bold")
# Out:
# Text(0.5, 1.0, 'rating of all movies')

# %% [markdown]
# # META SCORE

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=df['title'][:7],y=df['metascore'][:7], palette = 'husl')
g.set_title("Metascore of top rated movies", weight = "bold")
plt.show()

# %%
ax = sns.distplot(df['metascore']) # histogram distribution
# Out:
# C:\Users\abhim\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # ***Runtime***

# %% [markdown]
# ### GETTING TOP 5  movie HAVING LONGEST RUNTIME & SMALLEST RUNTIME

# %%
df1=df.sort_values('runtime',ascending=[False]).head(5)
df1.index= np.arange(1,6)
df1
# Out:
#    Unnamed: 0                              title  year  rating  metascore  \
# 1          21                 Gangs of Wasseypur  2012     8.2         89
# 2          52  Lagaan: Once Upon a Time in India  2001     8.1         84
# 3         230                        Mohabbatein  2000     7.1          0
# 4         138                       Jodhaa Akbar  2008     7.6         69
# 5         176        Kabhi Khushi Kabhie Gham...  2001     7.4          0
#
#   certificate     votes  runtime                                gener  \
# 1           A    83,759      321    Action, Comedy, Crime
# 2           U  1,05,968      224    Drama, Musical, Sport
# 3           U    27,562      216  Musical, Drama, Romance
# 4          UA    30,226      213   Action, Drama, History
# 5           U    45,451      210  Drama, Musical, Romance
#
#              director             star1                   star2  \
# 1      Anurag Kashyap    Manoj Bajpayee            Richa Chadha
# 2  Ashutosh Gowariker        Aamir Khan          Raghuvir Yadav
# 3       Aditya Chopra  Amitabh Bachchan          Shah Rukh Khan
# 4  Ashutosh Gowariker    Hrithik Roshan  Aishwarya Rai Bachchan
# 5         Karan Johar    Shah Rukh Khan                   Kajol
#
#                 star3             star4   gross
# 1  0wazuddin Siddiqui  Tigmanshu Dhulia       0
# 2         Gracy Singh    Rachel Shelley  $0.07M
# 3         Uday Chopra     Jugal Hansraj       0
# 4           Sonu Sood       Poo0m Sinha  $3.44M
# 5    Amitabh Bachchan    Hrithik Roshan  $2.90M

# %%
df1=df.sort_values('runtime',ascending=[False]).tail(5)
df1.index= np.arange(1,6)
df1
# Out:
#    Unnamed: 0                              title  year  rating  metascore  \
# 1         208             The Darjeeling Limited  2007     7.2         67
# 2         333             The Accidental Husband  2008     5.6         14
# 3         227  Harold & Kumar Go to White Castle  2004     7.1         64
# 4         373               Dragonball Evolution  2009     2.5         45
# 5         269    Beavis and Butt-Head Do America  1996     6.8         64
#
#   certificate     votes  runtime                                     gener  \
# 1           R  1,82,867       91      Adventure, Comedy, Drama
# 2       PG-13    23,407       90               Comedy, Romance
# 3           R  1,83,092       88             Adventure, Comedy
# 4           U    70,822       85    Action, Adventure, Fantasy
# 5       PG-13    51,820       81  Animation, Adventure, Comedy
#
#         director           star1                star2              star3  \
# 1   Wes Anderson     Owen Wilson         Adrien Brody  Jason Schwartzman
# 2  Griffin Dunne     Uma Thurman  Jeffrey Dean Morgan     Justi0 Machado
# 3   Danny Leiner        John Cho             Kal Penn        Ethan Embry
# 4     James Wong  Justin Chatwin       James Marsters       Chow Yun-Fat
# 5     Mike Judge    Mike de Seve       Brian Mulroney      Yvette Kaplan
#
#          star4    gross
# 1  Amara Karan  $11.90M
# 2  Colin Firth        0
# 3  Rob Tinkler  $18.23M
# 4  Emmy Rossum   $9.35M
# 5   Mike Judge  $63.07M

# %% [markdown]
# ### AVERAGE RUNTIME

# %%
runtime=df.groupby(["title"])["runtime"].sum()

# %%
average_runtime=df['runtime'].mean()
average_runtime
# Out:
# 142.6437994722955

# %%
runtime=runtime.reset_index()
runtime
# Out:
#                        title  runtime
# 0             0mastey London      128
# 1        0yak: The Real Hero      187
# 2                          2      148
# 3                   2 States      149
# 4                       2012      158
# ..                       ...      ...
# 373  Yeh Jawaani Hai Deewani      160
# 374                 Yes Boss      163
# 375                     Zero      164
# 376  Zindagi 0 Milegi Dobara      155
# 377   Zombieland: Double Tap       99
#
# [378 rows x 2 columns]

# %% [markdown]
# #### movie with maximum runtime

# %%
runtime["runtime"].max()
# Out:
# 353

# %%
runtime[runtime["runtime"]==353]
# Out:
#    title  runtime
# 95   Don      353

# %% [markdown]
# #### movie with minimum runtime

# %%
runtime["runtime"].min()
# Out:
# 81

# %%
runtime[runtime["runtime"]==81]
# Out:
#                               title  runtime
# 42  Beavis and Butt-Head Do America       81

# %% [markdown]
# ### list of head 10 movie having runtime above the avg runtime

# %%
runtime[runtime["runtime"]>average_runtime].head(10)
# Out:
#                          title  runtime
# 1          0yak: The Real Hero      187
# 2                            2      148
# 3                     2 States      149
# 4                         2012      158
# 5                     3 Idiots      170
# 7           A Passage to India      164
# 12                     Aankhen      165
# 14          Ae Dil Hai Mushkil      158
# 15                   Agneepath      174
# 17  Ajab Prem Ki Ghazab Kahani      150

# %% [markdown]
# ### ***list of head 10 anime having runtime below the avg runtime***

# %%
runtime[runtime["runtime"]<average_runtime].head(10)
# Out:
#                      title  runtime
# 0           0mastey London      128
# 6   A Good Day to Die Hard       98
# 8              A Wednesday      104
# 9                     A0nd      122
# 10                AK vs AK      108
# 11                   Aamir       99
# 13              Aashiqui 2      132
# 16                 Airlift      130
# 19               Andhadhun      139
# 21            Ankhon Dekhi      107

# %%
plt.figure(figsize=(7,7))
plt.hist(df["runtime"],bins=10)
plt.title("runtime frequency distribution")
plt.ylabel("frequency")
plt.xlabel("runtime")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Finding correlation

# %%
df.corr()
# Out:
#             Unnamed: 0    rating  metascore   runtime
# Unnamed: 0    1.000000 -0.870316  -0.268677 -0.135375
# rating       -0.870316  1.000000   0.255345  0.115798
# metascore    -0.268677  0.255345   1.000000 -0.076113
# runtime      -0.135375  0.115798  -0.076113  1.000000

# %%
numerical_attributes = ['rating', 'runtime','metascore']
df[numerical_attributes].hist(figsize = (15, 6), color = 'blue', edgecolor = 'red', layout = (2, 2));

# %% [markdown]
# # ***CERTIFICATE***

# %% [markdown]
# ### analyzing the movie content is sutiable for age group

# %%
series = df.certificate
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());
# Out:
# Printing the frequency
# UA          187
# U           100
# A            43
# PG-13        11
# R             8
# PG            7
# 13            6
# 16            5
# (Banned)      3
# 18            3
# 12+           2
# 15+           2
# Unrated       1
# 7             1
# Name: certificate, dtype: int64
# Printing the most frequent element of series
# 0    UA
# dtype: object

# %%
df['certificate']=df['certificate'].fillna('Not Rated')

certificates=df[df['certificate']!='Not Rated']['certificate']
fig,axs=plt.subplots(figsize=(20,5))
g=sns.countplot(certificates)
g.set_title("Count of Certificates provided", weight = "bold")
plt.show()
# Out:
# C:\Users\abhim\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
catdata=['certificate']
# pandas plot pie plot 
for i in catdata:
    plt.figure(figsize=(60,90))
    df[i].value_counts().plot.pie(autopct="%1.2f%%",fontsize=25)
    plt.title("certificate", fontsize=20)
    plt.show()

# %% [markdown]
# # Actors

# %% [markdown]
# #### Actor 1

# %%
series = df.star1
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());
# Out:
# Printing the frequency
# Shah Rukh Khan        29
# Akshay Kumar          29
# Salman Khan           19
# Hrithik Roshan        16
# Aamir Khan            15
#                       ..
# Sridevi                1
# Mithun Chakraborty     1
# Mark Rylance           1
# John Cho               1
# Uma Thurman            1
# Name: star1, Length: 157, dtype: int64
# Printing the most frequent element of series
# 0      Akshay Kumar
# 1    Shah Rukh Khan
# dtype: object

# %% [markdown]
# #### Actor2

# %%
series = df.star2
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());
# Out:
# Printing the frequency
# Katri0 Kaif                 12
# Deepika Padukone            10
# Akshay Kumar                 7
# Shah Rukh Khan               7
# Rani Mukerji                 7
#                             ..
# Pavail Gulati                1
# Maud Adams                   1
# Parambrata Chattopadhyay     1
# Aasif Mandvi                 1
# Dharmendra                   1
# Name: star2, Length: 230, dtype: int64
# Printing the most frequent element of series
# 0    Katri0 Kaif
# dtype: object

# %% [markdown]
# #### Actor 3

# %%
series = df.star3
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode())
# Out:
# Printing the frequency
# Priyanka Chopra    7
# Paresh Rawal       7
# Om Puri            5
# Amrish Puri        5
# Karee0 Kapoor      5
#                   ..
# Ranjit Batra       1
# Manoj Bajpayee     1
# Parvin Dabas       1
# Raghuvir Yadav     1
# Emma Stone         1
# Name: star3, Length: 279, dtype: int64
# Printing the most frequent element of series
# 0       Paresh Rawal
# 1    Priyanka Chopra
# dtype: object

# %% [markdown]
# #### Actor 4

# %%
series = df.star4
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode())
# Out:
# Printing the frequency
# Anupam Kher        7
# Saurabh Shukla     6
# Deepak Dobriyal    6
# Tabu               5
# Paresh Rawal       4
#                   ..
# Supriya Pathak     1
# Ma0v Vij           1
# Rajat Kapoor       1
# Payal 0ir          1
# Abigail Breslin    1
# Name: star4, Length: 304, dtype: int64
# Printing the most frequent element of series
# 0    Anupam Kher
# dtype: object

# %%
stars=['star4','star3','star2','star4']
fig,axs=plt.subplots(4,1,figsize=(20,20))
ax=0
for x in stars:
    axs[ax].bar(df[x].value_counts()[:10].index,df[x].value_counts()[:10])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %%
stars=['star1','star2','star3','star4']
fig,axs=plt.subplots(4,1,figsize=(20,10))
ax=0
for x in stars:
    s=df.groupby([x]).sum().reset_index()
    d=s.sort_values(['rating'],ascending=False)[:10]
    axs[ax].bar(d[x],d['rating'])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# # Directors

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=df['director'].value_counts()[:10].index,y=df['gross'].value_counts()[:10])
g.set_title("Directors", weight = "bold")
g.set_xlabel("Mostly Occurred", weight = "bold")
plt.show()

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.lineplot(x=df['director'].value_counts()[:10].index,y=df['year'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("director", weight = "bold")
plt.show()

# %% [markdown]
# # MOVIE GENRES

# %%
series = df.gener
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());
# Out:
# Printing the frequency
# Comedy, Drama, Romance                  39
# Action, Crime, Drama                    31
# Comedy, Drama                           27
# Drama, Romance                          19
# Action, Comedy, Crime                   14
#                                         ..
# Action, Comedy, Fantasy                  1
# Comedy, Horror                           1
# Crime, Drama, Music                      1
# Crime, Drama, History                    1
# Action, Biography, Crime                 1
# Name: gener, Length: 96, dtype: int64
# Printing the most frequent element of series
# 0    Comedy, Drama, Romance
# dtype: object

# %%
plt.figure(figsize=(20,20))
sns.countplot(data=df,y="gener")
plt.show()

# %%
plt.figure(figsize=(25,25))
sns.barplot(x='rating',y="gener",data=df)
plt.show()

# %%
from collections import Counter
genre=[]
for x in df['gener']:
    for y in x.split(','):
        genre.append(y.strip().lower())

count=Counter(genre)
count=count.most_common()[:10]
x,y=map(list,zip(*count))

fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(y,x)
g.set_ylabel("Genres", weight = "bold")
g.set_title("Top Ten Genres", weight = "bold")
plt.show()
# Out:
# C:\Users\abhim\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # maximum movies released in-

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=df['year'].value_counts()[:10].index,y=df['year'].value_counts()[:10])
g.set_title("Maximum movies released in-", weight = "bold")
g.set_xlabel("year")
plt.show()

# %% [markdown]
# # Appearances of Stars in Top voted movies

# %%
stars=['star1','star2','star3','star4']
fig,axs=plt.subplots(4,1,figsize=(20,15))
ax=0
for x in stars:
    s=df.groupby([x]).sum().reset_index()
    d=df.sort_values(['votes'],ascending=False)[:9]
    axs[ax].bar(d[x],d['votes'])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# # Conlusion

# %% [markdown]
# Here we have analyzed the data of top rated indian movies and by analyzing the data we have concluded the regarding points.<br>
# 1. we have seen top 10 high rated as well as low rated movies.
# 2. we have seen metascores of top rated movies.
# 3. we have seen which movie have the longest and smallest runtime.
# 4. we have observe the correlations.
# 5. we have seen the certificate provided to the movie.
# 6. appearence of the actors in the top rated movies and also directors.
# 7. we have seen gener of the movie which are repeatedly created.
# From above points we have concluded that it is easy to understand the data by visualization which are based on above points.
